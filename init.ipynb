# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting ta
#   Downloading ta-0.10.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pyarrow in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 2)) (8.0.0)
# Requirement already satisfied: plotly in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 3)) (5.9.0)
# Collecting schedule
#   Downloading schedule-1.1.0-py2.py3-none-any.whl (10 kB)
# Collecting dataframe_image
#   Downloading dataframe_image-0.1.2-py3-none-any.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 75.9 MB/s eta 0:00:00
# Collecting bokeh
#   Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 42.3 MB/s eta 0:00:00
# Collecting webdriver-manager
#   Downloading webdriver_manager-3.8.3-py2.py3-none-any.whl (26 kB)
# Collecting selenium
#   Downloading selenium-4.4.3-py3-none-any.whl (985 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 986.0/986.0 KB 81.1 MB/s eta 0:00:00
# Collecting imgkit
#   Downloading imgkit-1.2.2-py3-none-any.whl (10 kB)
# Collecting python-telegram-bot
#   Downloading python_telegram_bot-13.13-py3-none-any.whl (513 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 513.4/513.4 KB 67.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from ta->-r ./requirements.txt (line 1)) (1.21.6)
# Requirement already satisfied: pandas in /shared-libs/python3.7/py/lib/python3.7/site-packages (from ta->-r ./requirements.txt (line 1)) (1.2.5)
# Requirement already satisfied: tenacity>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from plotly->-r ./requirements.txt (line 3)) (8.0.1)
# Requirement already satisfied: packaging in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from dataframe_image->-r ./requirements.txt (line 5)) (21.3)
# Requirement already satisfied: aiohttp in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from dataframe_image->-r ./requirements.txt (line 5)) (3.8.1)
# Requirement already satisfied: beautifulsoup4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from dataframe_image->-r ./requirements.txt (line 5)) (4.11.1)
# Requirement already satisfied: matplotlib>=3.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from dataframe_image->-r ./requirements.txt (line 5)) (3.5.2)
# Requirement already satisfied: nbconvert>=5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from dataframe_image->-r ./requirements.txt (line 5)) (6.4.5)
# Requirement already satisfied: requests in /shared-libs/python3.7/py/lib/python3.7/site-packages (from dataframe_image->-r ./requirements.txt (line 5)) (2.28.1)
# Requirement already satisfied: mistune in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from dataframe_image->-r ./requirements.txt (line 5)) (0.8.4)
# Requirement already satisfied: Jinja2>=2.9 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bokeh->-r ./requirements.txt (line 6)) (2.11.3)
# Requirement already satisfied: typing-extensions>=3.10.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bokeh->-r ./requirements.txt (line 6)) (4.3.0)
# Requirement already satisfied: tornado>=5.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bokeh->-r ./requirements.txt (line 6)) (6.2)
# Collecting PyYAML>=3.10
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.3/596.3 KB 69.8 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=7.1.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from bokeh->-r ./requirements.txt (line 6)) (9.2.0)
# Requirement already satisfied: tqdm in /shared-libs/python3.7/py/lib/python3.7/site-packages (from webdriver-manager->-r ./requirements.txt (line 8)) (4.64.0)
# Collecting python-dotenv
#   Downloading python_dotenv-0.20.0-py3-none-any.whl (17 kB)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting trio~=0.17
#   Downloading trio-0.21.0-py3-none-any.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.0/359.0 KB 50.0 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2021.10.8 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from selenium->-r ./requirements.txt (line 9)) (2022.6.15)
# Requirement already satisfied: urllib3[socks]~=1.26 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from selenium->-r ./requirements.txt (line 9)) (1.26.11)
# Requirement already satisfied: six in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from imgkit->-r ./requirements.txt (line 10)) (1.16.0)
# Collecting APScheduler==3.6.3
#   Downloading APScheduler-3.6.3-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 KB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2018.6 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from python-telegram-bot->-r ./requirements.txt (line 11)) (2022.1)
# Collecting cachetools==4.2.2
#   Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: tzlocal>=1.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from APScheduler==3.6.3->python-telegram-bot->-r ./requirements.txt (line 11)) (4.2)
# Requirement already satisfied: setuptools>=0.7 in /root/venv/lib/python3.7/site-packages (from APScheduler==3.6.3->python-telegram-bot->-r ./requirements.txt (line 11)) (47.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from Jinja2>=2.9->bokeh->-r ./requirements.txt (line 6)) (2.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib>=3.1->dataframe_image->-r ./requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.1->dataframe_image->-r ./requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib>=3.1->dataframe_image->-r ./requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.1->dataframe_image->-r ./requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.1->dataframe_image->-r ./requirements.txt (line 5)) (4.34.4)
# Requirement already satisfied: pygments>=2.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (2.12.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (0.4)
# Requirement already satisfied: jupyter-core in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (4.11.1)
# Requirement already satisfied: nbformat>=4.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (5.4.0)
# Requirement already satisfied: defusedxml in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (0.2.2)
# Requirement already satisfied: traitlets>=5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (5.3.0)
# Requirement already satisfied: testpath in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (0.6.0)
# Requirement already satisfied: bleach in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: idna in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from trio~=0.17->selenium->-r ./requirements.txt (line 9)) (3.3)
# Requirement already satisfied: attrs>=19.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from trio~=0.17->selenium->-r ./requirements.txt (line 9)) (22.1.0)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting sortedcontainers
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Collecting PySocks!=1.5.7,<2.0,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->dataframe_image->-r ./requirements.txt (line 5)) (2.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->dataframe_image->-r ./requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->dataframe_image->-r ./requirements.txt (line 5)) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->dataframe_image->-r ./requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->dataframe_image->-r ./requirements.txt (line 5)) (1.8.1)
# Requirement already satisfied: asynctest==0.13.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->dataframe_image->-r ./requirements.txt (line 5)) (0.13.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp->dataframe_image->-r ./requirements.txt (line 5)) (6.0.2)
# Requirement already satisfied: soupsieve>1.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from beautifulsoup4->dataframe_image->-r ./requirements.txt (line 5)) (2.3.2.post1)
# Requirement already satisfied: jupyter-client>=6.1.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (7.3.4)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (1.5.5)
# Requirement already satisfied: jsonschema>=2.6 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.4->nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (3.2.0)
# Requirement already satisfied: fastjsonschema in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.4->nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (2.16.1)
# Requirement already satisfied: pytz-deprecation-shim in /shared-libs/python3.7/py/lib/python3.7/site-packages (from tzlocal>=1.2->APScheduler==3.6.3->python-telegram-bot->-r ./requirements.txt (line 11)) (0.1.0.post0)
# Requirement already satisfied: backports.zoneinfo in /shared-libs/python3.7/py/lib/python3.7/site-packages (from tzlocal>=1.2->APScheduler==3.6.3->python-telegram-bot->-r ./requirements.txt (line 11)) (0.2.1)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 KB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: webencodings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bleach->nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (0.5.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (0.18.1)
# Requirement already satisfied: importlib-metadata in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (4.12.0)
# Requirement already satisfied: pyzmq>=23.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (23.2.0)
# Requirement already satisfied: tzdata in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pytz-deprecation-shim->tzlocal>=1.2->APScheduler==3.6.3->python-telegram-bot->-r ./requirements.txt (line 11)) (2022.1)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata->jsonschema>=2.6->nbformat>=4.4->nbconvert>=5->dataframe_image->-r ./requirements.txt (line 5)) (3.8.1)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py): started
#   Building wheel for ta (setup.py): finished with status 'done'
#   Created wheel for ta: filename=ta-0.10.2-py3-none-any.whl size=29106 sha256=15f3598d8dfb1cdf5e450a697d805c0a02a87be3267b49d1d4af55f17dd57ae6
#   Stored in directory: /root/.cache/pip/wheels/31/31/f1/f2ff471bbc5b84a4b973698ceecdd453ae043971791adc3431
# Successfully built ta
# Installing collected packages: sortedcontainers, sniffio, schedule, PyYAML, python-dotenv, PySocks, outcome, imgkit, h11, cachetools, async-generator, wsproto, webdriver-manager, trio, bokeh, trio-websocket, ta, APScheduler, selenium, python-telegram-bot, dataframe_image
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.2.0
#     Not uninstalling cachetools at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'cachetools'. No files were found to uninstall.
# Successfully installed APScheduler-3.6.3 PySocks-1.7.1 PyYAML-6.0 async-generator-1.10 bokeh-2.4.3 cachetools-4.2.2 dataframe_image-0.1.2 h11-0.13.0 imgkit-1.2.2 outcome-1.2.0 python-dotenv-0.20.0 python-telegram-bot-13.13 schedule-1.1.0 selenium-4.4.3 sniffio-1.2.0 sortedcontainers-2.4.0 ta-0.10.2 trio-0.21.0 trio-websocket-0.9.2 webdriver-manager-3.8.3 wsproto-1.2.0
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=616d9311-e28a-4f68-a1e2-cfa37b447691' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
